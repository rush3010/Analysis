# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
import dabl

# %%
df=pd.read_excel("INX_Future_Inc_Employee_Performance_CDS_Project2_Data_V1.8.xls")
df
# Out:
#      EmpNumber  Age  Gender EducationBackground MaritalStatus  \
# 0     E1001000   32    Male           Marketing        Single
# 1     E1001006   47    Male           Marketing        Single
# 2     E1001007   40    Male       Life Sciences       Married
# 3     E1001009   41    Male     Human Resources      Divorced
# 4     E1001010   60    Male           Marketing        Single
# ...        ...  ...     ...                 ...           ...
# 1195   E100992   27  Female             Medical      Divorced
# 1196   E100993   37    Male       Life Sciences        Single
# 1197   E100994   50    Male             Medical       Married
# 1198   E100995   34  Female             Medical        Single
# 1199   E100998   24  Female       Life Sciences        Single
#
#         EmpDepartment        EmpJobRole BusinessTravelFrequency  \
# 0               Sales   Sales Executive           Travel_Rarely
# 1               Sales   Sales Executive           Travel_Rarely
# ...

# %%
df.shape
# Out:
# (1200, 28)

# %%
df.describe()
# Out:
#                Age  DistanceFromHome  EmpEducationLevel  \
# count  1200.000000       1200.000000         1200.00000
# mean     36.918333          9.165833            2.89250
# std       9.087289          8.176636            1.04412
# min      18.000000          1.000000            1.00000
# 25%      30.000000          2.000000            2.00000
# 50%      36.000000          7.000000            3.00000
# 75%      43.000000         14.000000            4.00000
# max      60.000000         29.000000            5.00000
#
#        EmpEnvironmentSatisfaction  EmpHourlyRate  EmpJobInvolvement  \
# count                 1200.000000    1200.000000        1200.000000
# mean                     2.715833      65.981667           2.731667
# std                      1.090599      20.211302           0.707164
# min                      1.000000      30.000000           1.000000
# 25%                      2.000000      48.000000           2.000000
# ...

# %%
df.corr()
# Out:
#                                    Age  DistanceFromHome  EmpEducationLevel  \
# Age                           1.000000          0.020937           0.207313
# DistanceFromHome              0.020937          1.000000           0.045856
# EmpEducationLevel             0.207313          0.045856           1.000000
# EmpEnvironmentSatisfaction    0.013814         -0.017719          -0.037103
# EmpHourlyRate                 0.062867          0.013730           0.014095
# EmpJobInvolvement             0.027216          0.003231           0.027544
# EmpJobLevel                   0.509139          0.017270           0.100734
# EmpJobSatisfaction           -0.002436         -0.003036           0.000357
# NumCompaniesWorked            0.284408         -0.021411           0.128674
# EmpLastSalaryHikePercent     -0.006105          0.044974           0.002358
# EmpRelationshipSatisfaction   0.049749         -0.009509          -0.016690
# ...

# %%
plt.figure(figsize=(20,10))
sns.heatmap(df.corr(),annot=True,fmt='.0%')
# Out:
# <AxesSubplot:>

# %%
dabl.plot(df,'EmpJobSatisfaction')
# Out:
# C:\Users\Admin\anaconda3\lib\site-packages\dabl\plot\supervised.py:546: FutureWarning: The second positional argument of plot is a Series 'y'. If passing a column name, use a keyword.
#   warnings.warn("The second positional argument of plot is a Series 'y'."
# Target looks like classification
# Linear Discriminant Analysis training set score: 0.259
# C:\Users\Admin\anaconda3\lib\site-packages\dabl\plot\utils.py:374: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(
# C:\Users\Admin\anaconda3\lib\site-packages\dabl\plot\utils.py:374: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(
# C:\Users\Admin\anaconda3\lib\site-packages\dabl\plot\utils.py:374: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(
# ...

# %%
df.columns
# Out:
# Index(['EmpNumber', 'Age', 'Gender', 'EducationBackground', 'MaritalStatus',
#        'EmpDepartment', 'EmpJobRole', 'BusinessTravelFrequency',
#        'DistanceFromHome', 'EmpEducationLevel', 'EmpEnvironmentSatisfaction',
#        'EmpHourlyRate', 'EmpJobInvolvement', 'EmpJobLevel',
#        'EmpJobSatisfaction', 'NumCompaniesWorked', 'OverTime',
#        'EmpLastSalaryHikePercent', 'EmpRelationshipSatisfaction',
#        'TotalWorkExperienceInYears', 'TrainingTimesLastYear',
#        'EmpWorkLifeBalance', 'ExperienceYearsAtThisCompany',
#        'ExperienceYearsInCurrentRole', 'YearsSinceLastPromotion',
#        'YearsWithCurrManager', 'Attrition', 'PerformanceRating'],
#       dtype='object')

# %%
#checking number of employess based on job satisfaction
sns.countplot(x=df['EmpJobSatisfaction'])
# Out:
# <AxesSubplot:xlabel='EmpJobSatisfaction', ylabel='count'>

# %%
plt.figure(figsize=(20,10))
sns.countplot(x='Age',hue='EmpJobSatisfaction',data=df,palette='Paired')
# Out:
# <AxesSubplot:xlabel='Age', ylabel='count'>

# %%
plt.figure(figsize=(20,10))
sns.countplot(x=df['EmpHourlyRate'])
# Out:
# <AxesSubplot:xlabel='EmpHourlyRate', ylabel='count'>

# %%
sns.countplot(x=df['PerformanceRating'])
# Out:
# <AxesSubplot:xlabel='PerformanceRating', ylabel='count'>

# %%
df=df[df['Attrition']=='No']
df
# Out:
#      EmpNumber  Age  Gender EducationBackground MaritalStatus  \
# 0     E1001000   32    Male           Marketing        Single
# 1     E1001006   47    Male           Marketing        Single
# 2     E1001007   40    Male       Life Sciences       Married
# 3     E1001009   41    Male     Human Resources      Divorced
# 4     E1001010   60    Male           Marketing        Single
# ...        ...  ...     ...                 ...           ...
# 1194   E100990   48    Male           Marketing       Married
# 1195   E100992   27  Female             Medical      Divorced
# 1196   E100993   37    Male       Life Sciences        Single
# 1197   E100994   50    Male             Medical       Married
# 1198   E100995   34  Female             Medical        Single
#
#         EmpDepartment        EmpJobRole BusinessTravelFrequency  \
# 0               Sales   Sales Executive           Travel_Rarely
# 1               Sales   Sales Executive           Travel_Rarely
# ...

# %%
a=df[df['YearsSinceLastPromotion']==0]
a
# Out:
#      EmpNumber  Age  Gender EducationBackground MaritalStatus EmpDepartment  \
# 0     E1001000   32    Male           Marketing        Single         Sales
# 8     E1001020   36  Female       Life Sciences       Married   Development
# 9     E1001021   38  Female       Life Sciences        Single   Development
# 13    E1001027   29    Male       Life Sciences        Single         Sales
# 19    E1001042   27  Female             Medical        Single   Development
# ...        ...  ...     ...                 ...           ...           ...
# 1187   E100977   36    Male             Medical      Divorced   Development
# 1190   E100983   23    Male             Medical       Married   Development
# 1192   E100987   38  Female           Marketing        Single         Sales
# 1195   E100992   27  Female             Medical      Divorced         Sales
# 1196   E100993   37    Male       Life Sciences        Single   Development
#
# ...

# %%
a1=a[a['ExperienceYearsAtThisCompany']>3]
a1
# Out:
#      EmpNumber  Age  Gender EducationBackground MaritalStatus EmpDepartment  \
# 0     E1001000   32    Male           Marketing        Single         Sales
# 8     E1001020   36  Female       Life Sciences       Married   Development
# 19    E1001042   27  Female             Medical        Single   Development
# 32    E1001067   36    Male       Life Sciences        Single         Sales
# 48    E1001093   50    Male             Medical       Married   Development
# ...        ...  ...     ...                 ...           ...           ...
# 1166   E100933   27  Female             Medical      Divorced   Development
# 1174   E100944   34  Female    Technical Degree      Divorced         Sales
# 1179   E100957   32  Female       Life Sciences       Married   Development
# 1192   E100987   38  Female           Marketing        Single         Sales
# 1195   E100992   27  Female             Medical      Divorced         Sales
#
# ...

# %%
a=a[a['EmpJobSatisfaction']==1]
a
# Out:
#      EmpNumber  Age  Gender EducationBackground MaritalStatus EmpDepartment  \
# 8     E1001020   36  Female       Life Sciences       Married   Development
# 19    E1001042   27  Female             Medical        Single   Development
# 22    E1001049   35  Female       Life Sciences      Divorced   Development
# 24    E1001053   34  Female       Life Sciences      Divorced   Development
# 32    E1001067   36    Male       Life Sciences        Single         Sales
# ...        ...  ...     ...                 ...           ...           ...
# 1096   E100812   41    Male           Marketing       Married         Sales
# 1145   E100893   40    Male               Other      Divorced         Sales
# 1170   E100940   38  Female       Life Sciences        Single   Development
# 1172   E100942   48  Female       Life Sciences       Married   Development
# 1190   E100983   23    Male             Medical       Married   Development
#
# ...

# %%
a=a[a['EmpEnvironmentSatisfaction']==1]
a
# Out:
#      EmpNumber  Age  Gender EducationBackground MaritalStatus  \
# 8     E1001020   36  Female       Life Sciences       Married
# 32    E1001067   36    Male       Life Sciences        Single
# 74    E1001132   25    Male             Medical        Single
# 85    E1001156   36    Male       Life Sciences       Married
# 290   E1001520   42  Female             Medical       Married
# 693   E1002239   38    Male       Life Sciences        Single
# 1190   E100983   23    Male             Medical       Married
#
#                EmpDepartment            EmpJobRole BusinessTravelFrequency  \
# 8                Development             Developer              Non-Travel
# 32                     Sales       Sales Executive              Non-Travel
# 74               Development             Developer           Travel_Rarely
# 85           Human Resources       Human Resources           Travel_Rarely
# 290   Research & Development     Research Director       Travel_Frequently
# ...

# %%
a=a[a['EmpRelationshipSatisfaction']==1]
a
# Out:
#      EmpNumber  Age  Gender EducationBackground MaritalStatus EmpDepartment  \
# 8     E1001020   36  Female       Life Sciences       Married   Development
# 693   E1002239   38    Male       Life Sciences        Single         Sales
# 1190   E100983   23    Male             Medical       Married   Development
#
#                 EmpJobRole BusinessTravelFrequency  DistanceFromHome  \
# 8                Developer              Non-Travel                 8
# 693   Sales Representative           Travel_Rarely                 1
# 1190             Developer           Travel_Rarely                 4
#
#       EmpEducationLevel  ...  EmpRelationshipSatisfaction  \
# 8                     3  ...                            1
# 693                   3  ...                            1
# 1190                  3  ...                            1
#
#       TotalWorkExperienceInYears  TrainingTimesLastYear  EmpWorkLifeBalance  \
# ...

# %%
a.loc[8,:]
#I think employee E1001020 needs serious attention
# Out:
# EmpNumber                            E1001020
# Age                                        36
# Gender                                 Female
# EducationBackground             Life Sciences
# MaritalStatus                         Married
# EmpDepartment                     Development
# EmpJobRole                          Developer
# BusinessTravelFrequency            Non-Travel
# DistanceFromHome                            8
# EmpEducationLevel                           3
# EmpEnvironmentSatisfaction                  1
# EmpHourlyRate                              63
# EmpJobInvolvement                           4
# EmpJobLevel                                 3
# EmpJobSatisfaction                          1
# NumCompaniesWorked                          9
# OverTime                                   No
# EmpLastSalaryHikePercent                   14
# EmpRelationshipSatisfaction                 1
# TotalWorkExperienceInYears                 10
# ...

# %%
#checking employes based on high hourly rate
b=df[df['EmpHourlyRate']>65]
b
# Out:
#      EmpNumber  Age  Gender EducationBackground MaritalStatus  \
# 3     E1001009   41    Male     Human Resources      Divorced
# 4     E1001010   60    Male           Marketing        Single
# 9     E1001021   38  Female       Life Sciences        Single
# 12    E1001025   30    Male           Marketing      Divorced
# 13    E1001027   29    Male       Life Sciences        Single
# ...        ...  ...     ...                 ...           ...
# 1186   E100976   54    Male             Medical       Married
# 1193   E100988   29    Male       Life Sciences      Divorced
# 1195   E100992   27  Female             Medical      Divorced
# 1196   E100993   37    Male       Life Sciences        Single
# 1197   E100994   50    Male             Medical       Married
#
#         EmpDepartment            EmpJobRole BusinessTravelFrequency  \
# 3     Human Resources               Manager           Travel_Rarely
# 4               Sales       Sales Executive           Travel_Rarely
# ...

# %%
b=b[b['EmpJobSatisfaction']==1]
b
# Out:
#      EmpNumber  Age  Gender EducationBackground MaritalStatus EmpDepartment  \
# 4     E1001010   60    Male           Marketing        Single         Sales
# 32    E1001067   36    Male       Life Sciences        Single         Sales
# 38    E1001077   54  Female             Medical      Divorced   Development
# 40    E1001080   37  Female       Life Sciences      Divorced   Development
# 41    E1001081   38  Female       Life Sciences        Single   Development
# ...        ...  ...     ...                 ...           ...           ...
# 1093   E100808   31    Male       Life Sciences       Married   Development
# 1097   E100814   28    Male             Medical      Divorced   Development
# 1115   E100845   30  Female               Other       Married         Sales
# 1152   E100903   41  Female       Life Sciences       Married         Sales
# 1153   E100908   52    Male    Technical Degree      Divorced   Development
#
# ...

# %%
b=b[b['EmpEnvironmentSatisfaction']==1]
b
# Out:
#      EmpNumber  Age  Gender EducationBackground MaritalStatus  \
# 4     E1001010   60    Male           Marketing        Single
# 32    E1001067   36    Male       Life Sciences        Single
# 41    E1001081   38  Female       Life Sciences        Single
# 85    E1001156   36    Male       Life Sciences       Married
# 100   E1001183   50    Male       Life Sciences      Divorced
# 353   E1001640   36  Female           Marketing       Married
# 400   E1001719   56  Female       Life Sciences       Married
# 620   E1002111   31  Female           Marketing       Married
# 655   E1002170   40    Male       Life Sciences      Divorced
# 817    E100359   59  Female       Life Sciences        Single
# 1024   E100703   45    Male       Life Sciences      Divorced
# 1088   E100800   54    Male             Medical       Married
#
#                EmpDepartment       EmpJobRole BusinessTravelFrequency  \
# 4                      Sales  Sales Executive           Travel_Rarely
# ...

# %%
b=b[b['EmpRelationshipSatisfaction']==1]
b
#I think Employes E1002170 and E100703 needs attention
# Out:
#      EmpNumber  Age Gender EducationBackground MaritalStatus  \
# 655   E1002170   40   Male       Life Sciences      Divorced
# 1024   E100703   45   Male       Life Sciences      Divorced
#
#                EmpDepartment      EmpJobRole BusinessTravelFrequency  \
# 655   Research & Development     Manager R&D           Travel_Rarely
# 1024             Development  Technical Lead       Travel_Frequently
#
#       DistanceFromHome  EmpEducationLevel  ...  EmpRelationshipSatisfaction  \
# 655                  1                  4  ...                            1
# 1024                 7                  3  ...                            1
#
#       TotalWorkExperienceInYears  TrainingTimesLastYear  EmpWorkLifeBalance  \
# 655                           22                      3                   3
# 1024                          24                      2                   3
#
#       ExperienceYearsAtThisCompany  ExperienceYearsInCurrentRole  \
# ...

# %%
#checking employes based on performance rating
c=df[df['PerformanceRating']==2]
c=c[c['EmpJobSatisfaction']==1]
c=c[c['EmpEnvironmentSatisfaction']==1]

# %%
c
#based on performnace rating, this all employes are not doing well
# Out:
#      EmpNumber  Age  Gender EducationBackground MaritalStatus  \
# 205   E1001361   26    Male             Medical       Married
# 291   E1001522   27    Male       Life Sciences       Married
# 353   E1001640   36  Female           Marketing       Married
# 457   E1001826   40    Male             Medical       Married
# 466   E1001838   33    Male       Life Sciences       Married
# 495   E1001890   45    Male           Marketing       Married
# 620   E1002111   31  Female           Marketing       Married
# 639   E1002141   46  Female    Technical Degree      Divorced
# 655   E1002170   40    Male       Life Sciences      Divorced
# 817    E100359   59  Female       Life Sciences        Single
# 1023   E100702   31    Male     Human Resources       Married
#
#                EmpDepartment             EmpJobRole BusinessTravelFrequency  \
# 205   Research & Development  Laboratory Technician           Travel_Rarely
# ...
